# %%
import os
print('sales1.excel' in os.listdir())
# Out:
# False

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
excel_file = pd.ExcelFile('sales1.xlsx')
excel_file.sheet_names
# Out:
# ['Customer', 'Orders']

# %%
import os
print(os.listdir())
# Out:
# ['%userprofile%', '.ipynb_checkpoints', '0409', '1033', '69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice.dll', '6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall.dll', '@AdvancedKeySettingsNotification.png', '@AppHelpToast.png', '@AudioToastIcon.png', '@BackgroundAccessToastIcon.png', '@bitlockertoastimage.png', '@edptoastimage.png', '@EnrollmentToastIcon.png', '@language_notification_icon.png', '@optionalfeatures.png', '@StorageSenseToastIcon.png', '@VpnToastIcon.png', '@windows-hello-V4.1.gif', '@WindowsHelloFaceToastIcon.png', '@WindowsUpdateToastIcon.contrast-black.png', '@WindowsUpdateToastIcon.contrast-white.png', '@WindowsUpdateToastIcon.png', '@WirelessDisplayToast.png', '@WLOGO_48x48.png', 'aadauthhelper.dll', 'aadcloudap.dll', 'aadjcsp.dll', 'aadtb.dll', 'aadWamExtension.dll', 'AarSvc.dll', 'AboutSettingsHandlers.dll', 'AboveLockAppHost.dll', 'accelerometerdll.DLL', 'accessibilitycpl.dll', 'accountaccessor.dll', 'AccountsRt.dll', 'AcGenral.dll', 'AcLayers.dll',
# ...

# %%
df = pd.read_excel('sales1.xlsx', sheet_name='Customer')
df.head()
# Out:
#   Customer ID    Customer Name    Segment
# 0    CG-12520      Claire Gute   Consumer
# 1    CG-12520      Claire Gute   Consumer
# 2    DV-13045  Darrin Van Huff  Corporate
# 3    SO-20335   Sean O'Donnell   Consumer
# 4    SO-20335   Sean O'Donnell   Consumer

# %%
df=pd.read_excel('sales1.xlsx', sheet_name='Orders')
df.head()
# Out:
#    Order Date   Ship Date       Ship Mode Customer ID        Country  \
# 0  08/11/2017  11/11/2017    Second Class    CG-12520  United States
# 1  08/11/2017  11/11/2017    Second Class    CG-12520  United States
# 2  12/06/2017  16/06/2017    Second Class    DV-13045  United States
# 3  11/10/2016  18/10/2016  Standard Class    SO-20335  United States
# 4  11/10/2016  18/10/2016  Standard Class    SO-20335  United States
#
#               City       State  Postal Code Region
# 0        Henderson    Kentucky      42420.0  South
# 1        Henderson    Kentucky      42420.0  South
# 2      Los Angeles  California      90036.0   West
# 3  Fort Lauderdale     Florida      33311.0  South
# 4  Fort Lauderdale     Florida      33311.0  South

# %%
import os
os.getcwd()
# Out:
# 'C:\\Windows\\system32'

# %%
import pandas as pd
file_path = 'sales3.xlsx' 
data_df = pd.read_excel(file_path, sheet_name='Data')
print(data_df.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df = pd.read_excel(file_path, sheet_name="Customer")
print(df.head())
# Out:
#   Customer ID    Customer Name   Segment
# 0    CG-12520      Claire Gute  Consumer
# 1    SO-20335   Sean O'Donnell  Consumer
# 2    BH-11710  Brosina Hoffman  Consumer
# 3    AA-10480     Andrew Allen  Consumer
# 4    IM-15070     Irene Maddox  Consumer

# %%
df = pd.read_excel(file_path, sheet_name="Products")
print(df.head())
# Out:
#         Product ID         Category Sub-Category  \
# 0  OFF-PA-10002365  Office Supplies        Paper
# 1  OFF-PA-10000249  Office Supplies        Paper
# 2  OFF-PA-10001569  Office Supplies        Paper
# 3  OFF-PA-10000587  Office Supplies        Paper
# 4  OFF-PA-10003892  Office Supplies        Paper
#
#                              Product Name
# 0                              Xerox 1967
# 1                       Easy-Staple Paper
# 2                               Xerox 232
# 3  Array Parchment Paper, Assorted Colors
# 4                              Xerox 1943

# %%
df = pd.read_excel(file_path, sheet_name="Order")
print(df.head())
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-121755 2017-01-16 2017-01-20    Second Class    EH-13945
# 1  CA-2017-101343 2017-07-17 2017-07-22  Standard Class    RA-19885
# 2  CA-2018-163405 2018-12-21 2018-12-25  Standard Class    BN-11515
# 3  CA-2015-159338 2015-06-25 2015-06-28     First Class    NS-18640
# 4  CA-2015-121664 2015-05-06 2015-05-10  Standard Class    HP-14815
#
#          Country         City       State  Postal Code Region  \
# 0  United States  Los Angeles  California        90049   West
# 1  United States  Los Angeles  California        90049   West
# 2  United States  Los Angeles  California        90049   West
# 3  United States  Los Angeles  California        90049   West
# 4  United States  Los Angeles  California        90049   West
#
#    Order Date (Year) Order Date (Quarter)  Order Date (Month Index)  \
# 0               2017                 Qtr1                         1
# ...

# %%
df = pd.read_excel(file_path, sheet_name="Sales Details")
print(df.head())
# Out:
# Empty DataFrame
# Columns: [Sales Details ]
# Index: []

# %%
df = pd.read_excel(file_path, sheet_name="Sales Details")
print(df.head())
# Out:
# Empty DataFrame
# Columns: [Sales Details ]
# Index: []

# %%
df = pd.read_excel(file_path, sheet_name="Sales Detalis")
print(df.head())
# Out:
#          Order ID       Product ID      Sales  Column1  Column2  Column3  \
# 0  CA-2017-152156  FUR-BO-10001798   261.9600      NaN      NaN      NaN
# 1  CA-2017-152156  FUR-CH-10000454   731.9400      NaN      NaN      NaN
# 2  CA-2017-114489  FUR-CH-10000454  1951.8400      NaN      NaN      NaN
# 3  CA-2017-138688  OFF-LA-10000240    14.6200      NaN      NaN      NaN
# 4  US-2016-108966  FUR-TA-10000577   957.5775      NaN      NaN      NaN
#
#    Column4
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df.shape
# Out:
# (9792, 7)

# %%
df.columns
# Out:
# Index(['Order ID', 'Product ID', 'Sales', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9792 entries, 0 to 9791
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order ID    9792 non-null   object
#  1   Product ID  9792 non-null   object
#  2   Sales       9792 non-null   float64
#  3   Column1     0 non-null      float64
#  4   Column2     0 non-null      float64
#  5   Column3     0 non-null      float64
#  6   Column4     0 non-null      float64
# dtypes: float64(5), object(2)
# memory usage: 535.6+ KB

# %%
df.head()
# Out:
#          Order ID       Product ID      Sales  Column1  Column2  Column3  \
# 0  CA-2017-152156  FUR-BO-10001798   261.9600      NaN      NaN      NaN
# 1  CA-2017-152156  FUR-CH-10000454   731.9400      NaN      NaN      NaN
# 2  CA-2017-114489  FUR-CH-10000454  1951.8400      NaN      NaN      NaN
# 3  CA-2017-138688  OFF-LA-10000240    14.6200      NaN      NaN      NaN
# 4  US-2016-108966  FUR-TA-10000577   957.5775      NaN      NaN      NaN
#
#    Column4
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df.describe()
# Out:
#               Sales  Column1  Column2  Column3  Column4
# count   9792.000000      0.0      0.0      0.0      0.0
# mean     230.928861      NaN      NaN      NaN      NaN
# std      627.074062      NaN      NaN      NaN      NaN
# min        0.444000      NaN      NaN      NaN      NaN
# 25%       17.235000      NaN      NaN      NaN      NaN
# 50%       54.432000      NaN      NaN      NaN      NaN
# 75%      210.568000      NaN      NaN      NaN      NaN
# max    22638.480000      NaN      NaN      NaN      NaN

# %%
df.isnull()
# Out:
#       Order ID  Product ID  Sales  Column1  Column2  Column3  Column4
# 0        False       False  False     True     True     True     True
# 1        False       False  False     True     True     True     True
# 2        False       False  False     True     True     True     True
# 3        False       False  False     True     True     True     True
# 4        False       False  False     True     True     True     True
# ...        ...         ...    ...      ...      ...      ...      ...
# 9787     False       False  False     True     True     True     True
# 9788     False       False  False     True     True     True     True
# 9789     False       False  False     True     True     True     True
# 9790     False       False  False     True     True     True     True
# 9791     False       False  False     True     True     True     True
#
# [9792 rows x 7 columns]

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
orders_df = pd.read_excel(file_path, sheet_name="Order")
missing_values = orders_df.isnull()
print(missing_values)
# Out:
#       Order ID  Order Date  Ship Date  Ship Mode  Customer ID  Country   City  \
# 0        False       False      False      False        False    False  False
# 1        False       False      False      False        False    False  False
# 2        False       False      False      False        False    False  False
# 3        False       False      False      False        False    False  False
# 4        False       False      False      False        False    False  False
# ...        ...         ...        ...        ...          ...      ...    ...
# 4917     False       False      False      False        False    False  False
# 4918     False       False      False      False        False    False  False
# 4919     False       False      False      False        False    False  False
# 4920     False       False      False      False        False    False  False
# 4921     False       False      False      False        False    False  False
#
# ...

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
orders_df = pd.read_excel(file_path, sheet_name="Products")
missing_values = orders_df.isnull()
print(missing_values)
# Out:
#       Product ID  Category  Sub-Category  Product Name
# 0          False     False         False         False
# 1          False     False         False         False
# 2          False     False         False         False
# 3          False     False         False         False
# 4          False     False         False         False
# ...          ...       ...           ...           ...
# 1811       False     False         False         False
# 1812       False     False         False         False
# 1813       False     False         False         False
# 1814       False     False         False         False
# 1815       False     False         False         False
#
# [1816 rows x 4 columns]

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
orders_df = pd.read_excel(file_path, sheet_name="Sales Detalis")
missing_values = orders_df.isnull()
print(missing_values)
# Out:
#       Order ID  Product ID  Sales  Column1  Column2  Column3  Column4
# 0        False       False  False     True     True     True     True
# 1        False       False  False     True     True     True     True
# 2        False       False  False     True     True     True     True
# 3        False       False  False     True     True     True     True
# 4        False       False  False     True     True     True     True
# ...        ...         ...    ...      ...      ...      ...      ...
# 9787     False       False  False     True     True     True     True
# 9788     False       False  False     True     True     True     True
# 9789     False       False  False     True     True     True     True
# 9790     False       False  False     True     True     True     True
# 9791     False       False  False     True     True     True     True
#
# [9792 rows x 7 columns]

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
orders_df = pd.read_excel(file_path, sheet_name="Customer")
missing_values = orders_df.isnull()
print(missing_values)
# Out:
#      Customer ID  Customer Name  Segment
# 0          False          False    False
# 1          False          False    False
# 2          False          False    False
# 3          False          False    False
# 4          False          False    False
# ..           ...            ...      ...
# 788        False          False    False
# 789        False          False    False
# 790        False          False    False
# 791        False          False    False
# 792        False          False    False
#
# [793 rows x 3 columns]

# %%
missing_values_count = orders_df.isnull().sum()
print(missing_values_count)
# Out:
# Customer ID      0
# Customer Name    0
# Segment          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Product ID       0
# Sales            0
# Column1       9792
# Column2       9792
# Column3       9792
# Column4       9792
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9787    False
# 9788    False
# 9789    False
# 9790    False
# 9791    False
# Length: 9792, dtype: bool

# %%
df. duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9787    False
# 9788    False
# 9789    False
# 9790    False
# 9791    False
# Length: 9792, dtype: bool>

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product ID, Sales, Column1, Column2, Column3, Column4]
# Index: []

# %%
df.describe()
# Out:
#               Sales  Column1  Column2  Column3  Column4
# count   9792.000000      0.0      0.0      0.0      0.0
# mean     230.928861      NaN      NaN      NaN      NaN
# std      627.074062      NaN      NaN      NaN      NaN
# min        0.444000      NaN      NaN      NaN      NaN
# 25%       17.235000      NaN      NaN      NaN      NaN
# 50%       54.432000      NaN      NaN      NaN      NaN
# 75%      210.568000      NaN      NaN      NaN      NaN
# max    22638.480000      NaN      NaN      NaN      NaN

# %%
print(df.columns)
# Out:
# Index(['Order ID', 'Product ID', 'Sales', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')

# %%
df['Order ID'].value_counts().head(32)
# Out:
# Order ID
# CA-2018-100111    14
# CA-2018-157987    12
# US-2017-108504    11
# CA-2017-165330    11
# CA-2016-131338    10
# CA-2017-105732    10
# US-2016-126977    10
# CA-2015-106439     9
# CA-2016-104346     9
# CA-2016-164882     9
# CA-2016-158421     9
# CA-2017-145177     9
# CA-2018-140949     9
# CA-2016-132626     9
# CA-2018-117457     9
# US-2017-114013     9
# US-2016-163433     9
# CA-2018-102925     8
# CA-2018-140872     8
# CA-2018-161956     8
# CA-2015-167927     8
# CA-2017-152730     8
# CA-2016-121720     8
# CA-2018-164756     8
# US-2018-118087     8
# CA-2018-156776     8
# CA-2016-167010     8
# US-2017-110156     8
# CA-2018-110905     8
# CA-2015-129364     8
# CA-2015-142769     8
# CA-2018-128363     7
# Name: count, dtype: int64

# %%
ANALYSIS

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Order ID', 'Product ID', 'Sales', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')

# %%
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
customer_df = pd.read_excel(file_path, sheet_name="Customer")
print(customer_df.columns)
# Out:
# Index(['Customer ID', 'Customer Name', 'Segment'], dtype='object')

# %%
customer_df.columns = customer_df.columns.str.strip()
print(customer_df.columns)
total_customers = customer_df['Customer ID'].nunique()
print(f"إجمالي عدد العملاء: {total_customers}")
# Out:
# Index(['Customer ID', 'Customer Name', 'Segment'], dtype='object')
# إجمالي عدد العملاء: 793

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
order_df = pd.read_excel(file_path, sheet_name="Order")
order_df.columns = order_df.columns.str.strip()
order_df['Order Date'] = pd.to_datetime(order_df['Order Date'], errors='coerce')
order_df['Year'] = order_df['Order Date'].dt.year
customers_per_year = order_df.groupby('Year')['Customer ID'].nunique()
print(customers_per_year)
# Out:
# Year
# 2015    589
# 2016    567
# 2017    635
# 2018    690
# Name: Customer ID, dtype: int64

# %%
print(order_df.columns)
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Order Date (Year)', 'Order Date (Quarter)', 'Order Date (Month Index)',
#        'Order Date (Month)', 'shipping time'],
#       dtype='object')

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
customer_df = pd.read_excel(file_path, sheet_name="Customer")
customer_df.columns = customer_df.columns.str.strip()
customers_per_segment = customer_df.groupby('Segment')['Customer ID'].nunique()
customers_percentage = (customers_per_segment / customers_per_segment.sum()) * 100
print(customers_percentage)
# Out:
# Segment
# Consumer       51.576293
# Corporate      29.760404
# Home Office    18.663304
# Name: Customer ID, dtype: float64

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
order_df = pd.read_excel(file_path, sheet_name="Order")
order_df.columns = order_df.columns.str.strip()
orders_per_customer = order_df.groupby('Customer ID')['Order ID'].nunique()
top_10_customers_orders = orders_per_customer.sort_values(ascending=False).head(10)
print(top_10_customers_orders)
# Out:
# Customer ID
# EP-13915    17
# CK-12205    13
# ZC-21910    13
# JE-15745    13
# PG-18820    13
# HG-14965    12
# CL-12565    12
# DK-12835    12
# SJ-20125    12
# NS-18640    12
# Name: Order ID, dtype: int64

# %%
print(sales_details_df.columns)
# Out:
# Index(['Sales Details'], dtype='object')

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
sales_details_df = pd.read_excel(file_path, sheet_name="Sales Details")
products_df = pd.read_excel(file_path, sheet_name="Products")
sales_details_df.columns = sales_details_df.columns.str.strip()
products_df.columns = products_df.columns.str.strip()
merged_df = pd.merge(sales_details_df, products_df, on="Product ID", how="inner")
total_sales_per_product = merged_df.groupby('Product Name')['Sales'].sum()
top_5_products = total_sales_per_product.sort_values(ascending=False).head(5)
print(top_5_products)

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
products_df = pd.read_excel(file_path, sheet_name="Products")
products_df.columns = products_df.columns.str.strip()
total_categories = products_df['Category'].nunique()
print(f"عدد الفئات: {total_categories}")
# Out:
# عدد الفئات: 3

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
products_df = pd.read_excel(file_path, sheet_name="Products")
products_df.columns = products_df.columns.str.strip()
total_subcategories = products_df['Sub-Category'].nunique()
print(f"عدد الـ Sub-Category: {total_subcategories}")
# Out:
# عدد الـ Sub-Category: 17

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
products_df = pd.read_excel(file_path, sheet_name="Products")
products_df.columns = products_df.columns.str.strip()
total_products = products_df['Product ID'].nunique()
print(f"عدد المنتجات: {total_products}")
# Out:
# عدد المنتجات: 1816

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
sales_details_df = pd.read_excel(file_path, sheet_name="Sales Detalis")
products_df = pd.read_excel(file_path, sheet_name="Products")
sales_details_df.columns = sales_details_df.columns.str.strip()
products_df.columns = products_df.columns.str.strip()
merged_df = pd.merge(sales_details_df, products_df, on="Product ID", how="inner")
total_sales_per_product = merged_df.groupby('Product Name')['Sales'].sum()
bottom_5_products = total_sales_per_product.sort_values(ascending=True).head(5)
print(bottom_5_products)
# Out:
# Product Name
# Eureka Disposable Bags For Sanitaire Vibra Groomer I Upright Vac    1.624
# Avery 5                                                             5.760
# Xerox 20                                                            6.480
# Grip Seal Envelopes                                                 7.072
# Acme Serrated Blade Letter Opener                                   7.632
# Name: Sales, dtype: float64

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
sales_details_df = pd.read_excel(file_path, sheet_name="Sales Detalis")
products_df = pd.read_excel(file_path, sheet_name="Products")
sales_details_df.columns = sales_details_df.columns.str.strip()
products_df.columns = products_df.columns.str.strip()
merged_df = pd.merge(sales_details_df, products_df, on="Product ID", how="inner")
total_sales_per_product = merged_df.groupby('Product Name')['Sales'].sum()
top_5_products = total_sales_per_product.sort_values(ascending=False).head(5)
print(top_5_products)
# Out:
# Product Name
# Canon Imageclass 2200 Advanced Copier                                          61599.824
# Fellowes Pb500 Electric Punch Plastic Comb Binding Machine With Manual Bind    27453.384
# Cisco Telepresence System Ex90 Videoconferencing Unit                          22638.480
# Hon 5400 Series Task Chairs For Big And Tall                                   21870.576
# Gbc Docubind Tl300 Electric Binding System                                     19823.479
# Name: Sales, dtype: float64

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
orders_df = pd.read_excel(file_path, sheet_name="Order")
orders_df.columns = orders_df.columns.str.strip()
print("Order DataFrame Columns:", orders_df.columns)
print("Does 'Ship Mode' exist?", 'Ship Mode' in orders_df.columns)
print("Does 'Shipping Time' exist?", 'Shipping Time' in orders_df.columns)
if 'Ship Mode' in orders_df.columns and 'Shipping Time' in orders_df.columns:
    avg_shipping_time_by_mode = orders_df.groupby('Ship Mode')['Shipping Time'].mean()
    print(avg_shipping_time_by_mode)
else:
    print("العمود 'Ship Mode' أو 'Shipping Time' غير موجود في البيانات.")
# Out:
# Order DataFrame Columns: Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Order Date (Year)', 'Order Date (Quarter)', 'Order Date (Month Index)',
#        'Order Date (Month)', 'shipping time'],
#       dtype='object')
# Does 'Ship Mode' exist? True
# Does 'Shipping Time' exist? False
# العمود 'Ship Mode' أو 'Shipping Time' غير موجود في البيانات.

# %%
import pandas as p
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
orders_df = pd.read_excel(file_path, sheet_name="Order")
orders_df.columns = orders_df.columns.str.strip()
orders_df['Order Date'] = pd.to_datetime(orders_df['Order Date'])
orders_df['Ship Date'] = pd.to_datetime(orders_df['Ship Date'])
orders_df['Shipping Days Delay'] = (orders_df['Ship Date'] - orders_df['Order Date']).dt.days
avg_shipping_delay_per_region = orders_df.groupby('Region')['Shipping Days Delay'].mean()
print(avg_shipping_delay_per_region)
# Out:
# Region
# Central    4.012111
# East       3.937911
# South      3.976543
# West       3.928166
# Name: Shipping Days Delay, dtype: float64

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
orders_df = pd.read_excel(file_path, sheet_name="Order")
orders_df.columns = orders_df.columns.str.strip()
orders_df['Order Date'] = pd.to_datetime(orders_df['Order Date'])
orders_df['Ship Date'] = pd.to_datetime(orders_df['Ship Date'])
orders_df['Shipping Time'] = (orders_df['Ship Date'] - orders_df['Order Date']).dt.days
avg_shipping_time = orders_df['Shipping Time'].mean()
print(f"متوسط وقت الشحن: {avg_shipping_time} أيام")
# Out:
# متوسط وقت الشحن: 3.958553433563592 أيام

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
sales_details_df = pd.read_excel(file_path, sheet_name="Sales Detalis")
sales_details_df.columns = sales_details_df.columns.str.strip()
print(sales_details_df.columns)
total_sales = sales_details_df['Sales'].sum()
print(f"مجموع المبيعات: {total_sales}")
# Out:
# Index(['Order ID', 'Product ID', 'Sales', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')
# مجموع المبيعات: 2261255.4107

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
sales_details_df = pd.read_excel(file_path, sheet_name="Sales Detalis")
orders_df = pd.read_excel(file_path, sheet_name="Order")
saes_details_df.columns = sales_details_df.columns.str.strip()
orders_df.columns = orders_df.columns.str.strip()
merged_df = pd.merge(sales_details_df, orders_df, on="Order ID", how="inner")
print(merged_df.columns)
sales_per_region = merged_df.groupby('Region')['Sales'].sum()
print(sales_per_region)
# Out:
# Index(['Order ID', 'Product ID', 'Sales', 'Column1', 'Column2', 'Column3',
#        'Column4', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Order Date (Year)', 'Order Date (Quarter)', 'Order Date (Month Index)',
#        'Order Date (Month)', 'shipping time'],
#       dtype='object')
# Region
# Central    492646.9132
# East       669237.3540
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %%
import pandas as pd
file_path = r"D:\رواد مصر 2025\practice , assignments\technical assignment\Final project\اخر تعديل 15-10\final normalization\نهائي\sales3.xlsx"
sales_details_df = pd.read_excel(file_path, sheet_name="Sales Detalis")
orders_df = pd.read_excel(file_path, sheet_name="Order")
sales_details_df.columns = sales_details_df.columns.str.strip()
orders_df.columns = orders_df.columns.str.strip()
merged_df = pd.merge(sales_details_df, orders_df, on="Order ID", how="inner")
sales_per_state = merged_df.groupby('State')['Sales'].sum()
top_3_states = sales_per_state.sort_values(ascending=False).head(3)
print("Top 3 States by Sales:")
print(top_3_states)
less_3_states = sales_per_state.sort_values(ascending=True).head(3)
print("Less 3 States by Sales:")
print(less_3_states)
# Out:
# Top 3 States by Sales:
# State
# California    446306.4635
# New York      306361.1470
# Texas         168572.5322
# Name: Sales, dtype: float64
# Less 3 States by Sales:
# State
# North Dakota      919.910
# West Virginia    1209.824
# Maine            1270.530
# Name: Sales, dtype: float64
